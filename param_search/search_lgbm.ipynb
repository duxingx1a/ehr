# %%
import pandas as pd
import serach_utils
data_mean=pd.read_csv('../data_cleaned/ver-noelectrolyte-crystal_removed_history_removed_mean.csv')
X_train,X_test,Y_train,Y_test=serach_utils.get_train_test(data_mean)

# %%
from lightgbm import LGBMClassifier
from skopt.space import Integer, Real

param_space_lightGBM = {
    'boosting_type': ['gbdt'],  # 提升类型
    'num_leaves': Integer(30, 100),  # 叶子数
    'max_depth': Integer(3, 10),  # 最大深度
    'learning_rate': Real(0.01, 0.2),  # 学习率
    'n_estimators': Integer(100, 500)  # 基估计器的数量
}

# 初始化LightGBM分类器
model = LGBMClassifier(n_jobs=-1,class_weight={0: 1, 1: 30})
serach_utils.search_params(param_space_lightGBM, model, X_train, Y_train)

#需要跑10h+
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 2/5; 1/1] START boosting_type=gbdt, learning_rate=0.14826789120369177, max_depth=10, n_estimators=226, num_leaves=77
# [CV 3/5; 1/1] START boosting_type=gbdt, learning_rate=0.14826789120369177, max_depth=10, n_estimators=226, num_leaves=77
# [CV 4/5; 1/1] START boosting_type=gbdt, learning_rate=0.14826789120369177, max_depth=10, n_estimators=226, num_leaves=77
# [CV 1/5; 1/1] START boosting_type=gbdt, learning_rate=0.14826789120369177, max_depth=10, n_estimators=226, num_leaves=77
# [CV 5/5; 1/1] START boosting_type=gbdt, learning_rate=0.14826789120369177, max_depth=10, n_estimators=226, num_leaves=77
# [LightGBM] [Info] Number of positive: 14908, number of negative: 405360
# [LightGBM] [Info] Number of positive: 14908, number of negative: 405361
# [LightGBM] [Info] Number of positive: 14908, number of negative: 405361
# [LightGBM] [Info] Number of positive: 14908, number of negative: 405361
# ...
