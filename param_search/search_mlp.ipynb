# %%
import pandas as pd
import serach_utils
data_mean=pd.read_csv('../data_cleaned/ver-noelectrolyte-logtransform_mean.csv')
X_train,X_test,Y_train,Y_test=serach_utils.get_train_test(data_mean)

# %%
from sklearn.neural_network import MLPClassifier
from skopt.space import Integer, Real

param_space = {
    'hidden_layer_sizes': Integer(200, 500),  # 隐藏层神经元数量
    'activation': ['identity', 'logistic', 'tanh', 'relu'],  # 激活函数
    'solver': ['lbfgs', 'sgd', 'adam'],  # 优化算法
    'alpha': Real(1e-6, 1e-2),  # L2 正则化项的参数
    'learning_rate': ['constant', 'invscaling', 'adaptive'],  # 学习率更新方式
    'learning_rate_init': Real(0.001, 0.1),  # 初始学习率
    'max_iter': Integer(100, 1000)  # 最大迭代次数
}

# 初始化 MLP 分类器
model = MLPClassifier(random_state=42)
search_utils.search_params(param_space, model, X_train, Y_train)
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
