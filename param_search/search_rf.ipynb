# %%
import pandas as pd
import serach_utils
data_mean=pd.read_csv('../data_cleaned/ver-noelectrolyte-crystal_removed_history_removed_mean.csv')
X_train,X_test,Y_train,Y_test=serach_utils.get_train_test(data_mean)

# %%
from sklearn.ensemble import RandomForestClassifier
from skopt.space import Integer

param_space_randomForest = {
    'n_estimators': Integer(50, 200),  # 基估计器的数量
    'max_depth': Integer(3, 20),  # 最大深度
    'min_samples_split': Integer(2, 10),  # 内部节点再划分所需最小样本数
    'min_samples_leaf': Integer(1, 5)  # 叶子节点最少样本数
}

# 初始化RandomForest分类器
model = RandomForestClassifier(n_jobs=-1, random_state=42,class_weight={0: 1, 1: 30})
serach_utils.search_params(param_space_randomForest, model, X_train, Y_train)
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START max_depth=10, min_samples_leaf=4, min_samples_split=9, n_estimators=97
# [CV 3/5; 1/1] START max_depth=10, min_samples_leaf=4, min_samples_split=9, n_estimators=97
# [CV 4/5; 1/1] START max_depth=10, min_samples_leaf=4, min_samples_split=9, n_estimators=97
# [CV 2/5; 1/1] START max_depth=10, min_samples_leaf=4, min_samples_split=9, n_estimators=97
# [CV 5/5; 1/1] START max_depth=10, min_samples_leaf=4, min_samples_split=9, n_estimators=97
# [CV 1/5; 1/1] END max_depth=10, min_samples_leaf=4, min_samples_split=9, n_estimators=97;, score=0.695 total time= 1.0min
# [CV 4/5; 1/1] END max_depth=10, min_samples_leaf=4, min_samples_split=9, n_estimators=97;, score=0.684 total time= 1.0min
# [CV 3/5; 1/1] END max_depth=10, min_samples_leaf=4, min_samples_split=9, n_estimators=97;, score=0.700 total time= 1.0min
# ...
