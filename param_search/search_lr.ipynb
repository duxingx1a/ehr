# %%
import pandas as pd
import serach_utils
data_mean=pd.read_csv('../data_cleaned/ver-noelectrolyte-logtransform_mean.csv')
X_train,X_test,Y_train,Y_test=serach_utils.get_train_test(data_mean)

# %%
from sklearn.linear_model import LogisticRegression
from skopt.space import Real

param_space_logisticRegression = {
    'C': Real(0.1, 10),  # 逆正则化强度
    'solver': ['lbfgs', 'liblinear']  # 求解器
}

# 初始化LogisticRegression分类器
model = LogisticRegression(class_weight={0: 1, 1: 9}, max_iter=1000)
serach_utils.search_params(param_space_logisticRegression, model, X_train, Y_train)
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 4/5; 1/1] START C=4.160029192647807, solver=liblinear.......................
# [CV 1/5; 1/1] START C=4.160029192647807, solver=liblinear.......................
# [CV 5/5; 1/1] START C=4.160029192647807, solver=liblinear.......................
# [CV 2/5; 1/1] START C=4.160029192647807, solver=liblinear.......................
# [CV 3/5; 1/1] START C=4.160029192647807, solver=liblinear.......................
# [CV 1/5; 1/1] END C=4.160029192647807, solver=liblinear;, score=0.671 total time=37.3min
# [CV 5/5; 1/1] END C=4.160029192647807, solver=liblinear;, score=0.666 total time=37.4min
# [CV 2/5; 1/1] END C=4.160029192647807, solver=liblinear;, score=0.668 total time=42.3min
# [CV 3/5; 1/1] END C=4.160029192647807, solver=liblinear;, score=0.669 total time=42.4min
# [CV 4/5; 1/1] END C=4.160029192647807, solver=liblinear;, score=0.669 total time=48.4min
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# ...
