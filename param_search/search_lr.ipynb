# %%
import pandas as pd
import serach_utils
data_mean=pd.read_csv('../data_cleaned/ver-noelectrolyte-logtransform_mean.csv')
X_train,X_test,Y_train,Y_test=serach_utils.get_train_test(data_mean)

# %%
from sklearn.linear_model import LogisticRegression
from skopt.space import Real

param_space_logisticRegression = {
    'C': Real(0.1, 10),  # 逆正则化强度
    'solver': ['lbfgs', 'liblinear']  # 求解器
}

# 初始化LogisticRegression分类器
model = LogisticRegression()
serach_utils.search_params(param_space_logisticRegression, model, X_train, Y_train)
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START C=4.160029192647807, solver=liblinear.......................
# [CV 2/5; 1/1] START C=4.160029192647807, solver=liblinear.......................
# [CV 5/5; 1/1] START C=4.160029192647807, solver=liblinear.......................
# [CV 4/5; 1/1] START C=4.160029192647807, solver=liblinear.......................
# [CV 3/5; 1/1] START C=4.160029192647807, solver=liblinear.......................
# [CV 5/5; 1/1] END C=4.160029192647807, solver=liblinear;, score=0.662 total time= 4.0min
# [CV 1/5; 1/1] END C=4.160029192647807, solver=liblinear;, score=0.669 total time= 4.9min
# [CV 2/5; 1/1] END C=4.160029192647807, solver=liblinear;, score=0.666 total time= 6.9min
# [CV 4/5; 1/1] END C=4.160029192647807, solver=liblinear;, score=0.668 total time= 7.5min
# [CV 3/5; 1/1] END C=4.160029192647807, solver=liblinear;, score=0.669 total time= 8.1min
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START C=8.390144719977515, solver=liblinear.......................
# [CV 2/5; 1/1] START C=8.390144719977515, solver=liblinear.......................
# [CV 3/5; 1/1] START C=8.390144719977515, solver=liblinear.......................
# [CV 4/5; 1/1] START C=8.390144719977515, solver=liblinear.......................
# [CV 5/5; 1/1] START C=8.390144719977515, solver=liblinear.......................
# [CV 3/5; 1/1] END C=8.390144719977515, solver=liblinear;, score=0.668 total time= 8.4min
# [CV 1/5; 1/1] END C=8.390144719977515, solver=liblinear;, score=0.670 total time= 8.5min
# [CV 5/5; 1/1] END C=8.390144719977515, solver=liblinear;, score=0.664 total time= 9.3min
# [CV 2/5; 1/1] END C=8.390144719977515, solver=liblinear;, score=0.666 total time=10.0min
# [CV 4/5; 1/1] END C=8.390144719977515, solver=liblinear;, score=0.668 total time=10.3min
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START C=4.503841871781403, solver=liblinear.......................
# [CV 2/5; 1/1] START C=4.503841871781403, solver=liblinear.......................
# [CV 3/5; 1/1] START C=4.503841871781403, solver=liblinear.......................
# [CV 4/5; 1/1] START C=4.503841871781403, solver=liblinear.......................
# [CV 5/5; 1/1] START C=4.503841871781403, solver=liblinear.......................
# [CV 3/5; 1/1] END C=4.503841871781403, solver=liblinear;, score=0.668 total time= 7.8min
# [CV 1/5; 1/1] END C=4.503841871781403, solver=liblinear;, score=0.670 total time= 7.9min
# [CV 5/5; 1/1] END C=4.503841871781403, solver=liblinear;, score=0.664 total time= 8.6min
# [CV 2/5; 1/1] END C=4.503841871781403, solver=liblinear;, score=0.667 total time= 8.8min
# [CV 4/5; 1/1] END C=4.503841871781403, solver=liblinear;, score=0.668 total time= 9.2min
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START C=8.142720284737898, solver=lbfgs...........................
# [CV 2/5; 1/1] START C=8.142720284737898, solver=lbfgs...........................
# [CV 3/5; 1/1] START C=8.142720284737898, solver=lbfgs...........................
# [CV 4/5; 1/1] START C=8.142720284737898, solver=lbfgs...........................
# [CV 5/5; 1/1] START C=8.142720284737898, solver=lbfgs...........................
# /home/mclab/miniconda3/envs/ydl/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 1/5; 1/1] END C=8.142720284737898, solver=lbfgs;, score=0.641 total time= 1.4min
# /home/mclab/miniconda3/envs/ydl/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 2/5; 1/1] END C=8.142720284737898, solver=lbfgs;, score=0.638 total time= 1.4min
# /home/mclab/miniconda3/envs/ydl/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 3/5; 1/1] END C=8.142720284737898, solver=lbfgs;, score=0.640 total time= 1.5min
# /home/mclab/miniconda3/envs/ydl/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 5/5; 1/1] END C=8.142720284737898, solver=lbfgs;, score=0.633 total time= 1.5min
# /home/mclab/miniconda3/envs/ydl/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 4/5; 1/1] END C=8.142720284737898, solver=lbfgs;, score=0.640 total time= 1.5min
# [CV 1/5; 1/1] START C=8.015579071911015, solver=lbfgs...........................
# [CV 4/5; 1/1] START C=8.015579071911015, solver=lbfgs...........................
# [CV 3/5; 1/1] START C=8.015579071911015, solver=lbfgs...........................
# [CV 5/5; 1/1] START C=8.015579071911015, solver=lbfgs...........................
# [CV 2/5; 1/1] START C=8.015579071911015, solver=lbfgs...........................
# /home/mclab/miniconda3/envs/ydl/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 2/5; 1/1] END C=8.015579071911015, solver=lbfgs;, score=0.639 total time=  46.1s
# /home/mclab/miniconda3/envs/ydl/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 1/5; 1/1] END C=8.015579071911015, solver=lbfgs;, score=0.641 total time=  57.9s
# /home/mclab/miniconda3/envs/ydl/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 5/5; 1/1] END C=8.015579071911015, solver=lbfgs;, score=0.633 total time=  57.3s
# /home/mclab/miniconda3/envs/ydl/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 3/5; 1/1] END C=8.015579071911015, solver=lbfgs;, score=0.641 total time= 1.0min
# /home/mclab/miniconda3/envs/ydl/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 4/5; 1/1] END C=8.015579071911015, solver=lbfgs;, score=0.641 total time= 1.2min
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 5/5; 1/1] START C=7.366877378057127, solver=liblinear.......................
# [CV 4/5; 1/1] START C=7.366877378057127, solver=liblinear.......................
# [CV 2/5; 1/1] START C=7.366877378057127, solver=liblinear.......................
# [CV 1/5; 1/1] START C=7.366877378057127, solver=liblinear.......................
# [CV 3/5; 1/1] START C=7.366877378057127, solver=liblinear.......................
# [CV 5/5; 1/1] END C=7.366877378057127, solver=liblinear;, score=0.664 total time= 8.0min
# [CV 4/5; 1/1] END C=7.366877378057127, solver=liblinear;, score=0.668 total time= 8.0min
# [CV 3/5; 1/1] END C=7.366877378057127, solver=liblinear;, score=0.668 total time= 8.3min
# [CV 2/5; 1/1] END C=7.366877378057127, solver=liblinear;, score=0.667 total time= 8.9min
# [CV 1/5; 1/1] END C=7.366877378057127, solver=liblinear;, score=0.670 total time= 9.7min
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START C=6.209085649172931, solver=liblinear.......................
# [CV 2/5; 1/1] START C=6.209085649172931, solver=liblinear.......................
# [CV 3/5; 1/1] START C=6.209085649172931, solver=liblinear.......................
# [CV 4/5; 1/1] START C=6.209085649172931, solver=liblinear.......................
# [CV 5/5; 1/1] START C=6.209085649172931, solver=liblinear.......................
# [CV 5/5; 1/1] END C=6.209085649172931, solver=liblinear;, score=0.663 total time= 6.0min
# [CV 3/5; 1/1] END C=6.209085649172931, solver=liblinear;, score=0.668 total time= 7.7min
# [CV 4/5; 1/1] END C=6.209085649172931, solver=liblinear;, score=0.667 total time= 8.0min
# [CV 2/5; 1/1] END C=6.209085649172931, solver=liblinear;, score=0.667 total time= 9.1min
# [CV 1/5; 1/1] END C=6.209085649172931, solver=liblinear;, score=0.670 total time=10.3min
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START C=5.479690370134094, solver=liblinear.......................
# [CV 2/5; 1/1] START C=5.479690370134094, solver=liblinear.......................
# [CV 3/5; 1/1] START C=5.479690370134094, solver=liblinear.......................
# [CV 4/5; 1/1] START C=5.479690370134094, solver=liblinear.......................
# [CV 5/5; 1/1] START C=5.479690370134094, solver=liblinear.......................
# [CV 1/5; 1/1] END C=5.479690370134094, solver=liblinear;, score=0.670 total time= 8.8min
# [CV 5/5; 1/1] END C=5.479690370134094, solver=liblinear;, score=0.664 total time= 8.9min
# [CV 3/5; 1/1] END C=5.479690370134094, solver=liblinear;, score=0.668 total time= 9.0min
# [CV 4/5; 1/1] END C=5.479690370134094, solver=liblinear;, score=0.668 total time= 9.4min
# [CV 2/5; 1/1] END C=5.479690370134094, solver=liblinear;, score=0.667 total time= 9.6min
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START C=9.55923206446829, solver=liblinear........................
# [CV 2/5; 1/1] START C=9.55923206446829, solver=liblinear........................
# [CV 3/5; 1/1] START C=9.55923206446829, solver=liblinear........................
# [CV 4/5; 1/1] START C=9.55923206446829, solver=liblinear........................
# [CV 5/5; 1/1] START C=9.55923206446829, solver=liblinear........................
# [CV 5/5; 1/1] END C=9.55923206446829, solver=liblinear;, score=0.664 total time= 7.2min
# [CV 1/5; 1/1] END C=9.55923206446829, solver=liblinear;, score=0.670 total time= 9.1min
# [CV 3/5; 1/1] END C=9.55923206446829, solver=liblinear;, score=0.668 total time= 9.5min
# [CV 2/5; 1/1] END C=9.55923206446829, solver=liblinear;, score=0.667 total time=10.2min
# [CV 4/5; 1/1] END C=9.55923206446829, solver=liblinear;, score=0.668 total time=11.8min
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START C=0.13594004182195796, solver=liblinear.....................
# [CV 2/5; 1/1] START C=0.13594004182195796, solver=liblinear.....................
# [CV 3/5; 1/1] START C=0.13594004182195796, solver=liblinear.....................
# [CV 4/5; 1/1] START C=0.13594004182195796, solver=liblinear.....................
# [CV 5/5; 1/1] START C=0.13594004182195796, solver=liblinear.....................
# [CV 3/5; 1/1] END C=0.13594004182195796, solver=liblinear;, score=0.668 total time= 6.8min
# [CV 5/5; 1/1] END C=0.13594004182195796, solver=liblinear;, score=0.664 total time= 6.8min
# [CV 1/5; 1/1] END C=0.13594004182195796, solver=liblinear;, score=0.670 total time= 6.9min
# [CV 2/5; 1/1] END C=0.13594004182195796, solver=liblinear;, score=0.666 total time= 7.1min
# [CV 4/5; 1/1] END C=0.13594004182195796, solver=liblinear;, score=0.668 total time= 9.2min
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START C=9.487738803371146, solver=lbfgs...........................
# [CV 2/5; 1/1] START C=9.487738803371146, solver=lbfgs...........................
# [CV 3/5; 1/1] START C=9.487738803371146, solver=lbfgs...........................
# [CV 4/5; 1/1] START C=9.487738803371146, solver=lbfgs...........................
# [CV 5/5; 1/1] START C=9.487738803371146, solver=lbfgs...........................
# /home/mclab/miniconda3/envs/ydl/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 2/5; 1/1] END C=9.487738803371146, solver=lbfgs;, score=0.640 total time=  25.5s
# /home/mclab/miniconda3/envs/ydl/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 1/5; 1/1] END C=9.487738803371146, solver=lbfgs;, score=0.641 total time=  34.2s
# /home/mclab/miniconda3/envs/ydl/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 3/5; 1/1] END C=9.487738803371146, solver=lbfgs;, score=0.640 total time=  31.7s
# /home/mclab/miniconda3/envs/ydl/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 4/5; 1/1] END C=9.487738803371146, solver=lbfgs;, score=0.640 total time=  35.3s
# /home/mclab/miniconda3/envs/ydl/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 5/5; 1/1] END C=9.487738803371146, solver=lbfgs;, score=0.634 total time=  36.6s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 3/5; 1/1] START C=5.691079987002053, solver=liblinear.......................
# [CV 5/5; 1/1] START C=5.691079987002053, solver=liblinear.......................
# [CV 1/5; 1/1] START C=5.691079987002053, solver=liblinear.......................
# [CV 4/5; 1/1] START C=5.691079987002053, solver=liblinear.......................
# [CV 2/5; 1/1] START C=5.691079987002053, solver=liblinear.......................
# [CV 4/5; 1/1] END C=5.691079987002053, solver=liblinear;, score=0.667 total time= 5.8min
# [CV 3/5; 1/1] END C=5.691079987002053, solver=liblinear;, score=0.668 total time= 6.5min
# [CV 5/5; 1/1] END C=5.691079987002053, solver=liblinear;, score=0.664 total time= 6.6min
# [CV 1/5; 1/1] END C=5.691079987002053, solver=liblinear;, score=0.670 total time= 6.6min
# [CV 2/5; 1/1] END C=5.691079987002053, solver=liblinear;, score=0.666 total time= 6.5min
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START C=10.0, solver=liblinear....................................
# [CV 2/5; 1/1] START C=10.0, solver=liblinear....................................
# [CV 3/5; 1/1] START C=10.0, solver=liblinear....................................
# [CV 4/5; 1/1] START C=10.0, solver=liblinear....................................
# [CV 5/5; 1/1] START C=10.0, solver=liblinear....................................
# [CV 1/5; 1/1] END .....C=10.0, solver=liblinear;, score=0.670 total time= 4.6min
# [CV 2/5; 1/1] END .....C=10.0, solver=liblinear;, score=0.666 total time= 4.8min
# [CV 4/5; 1/1] END .....C=10.0, solver=liblinear;, score=0.668 total time= 5.0min
# [CV 5/5; 1/1] END .....C=10.0, solver=liblinear;, score=0.664 total time= 5.1min
# [CV 3/5; 1/1] END .....C=10.0, solver=liblinear;, score=0.668 total time= 5.1min
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START C=5.03762254656649, solver=liblinear........................
# [CV 2/5; 1/1] START C=5.03762254656649, solver=liblinear........................
# [CV 3/5; 1/1] START C=5.03762254656649, solver=liblinear........................
# [CV 4/5; 1/1] START C=5.03762254656649, solver=liblinear........................
# [CV 5/5; 1/1] START C=5.03762254656649, solver=liblinear........................
# [CV 5/5; 1/1] END C=5.03762254656649, solver=liblinear;, score=0.664 total time= 6.1min
# [CV 4/5; 1/1] END C=5.03762254656649, solver=liblinear;, score=0.667 total time= 6.6min
# [CV 1/5; 1/1] END C=5.03762254656649, solver=liblinear;, score=0.670 total time= 6.7min
# [CV 2/5; 1/1] END C=5.03762254656649, solver=liblinear;, score=0.667 total time= 6.9min
# [CV 3/5; 1/1] END C=5.03762254656649, solver=liblinear;, score=0.668 total time= 7.0min
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START C=4.8156365982183, solver=lbfgs.............................
# [CV 2/5; 1/1] START C=4.8156365982183, solver=lbfgs.............................
# [CV 3/5; 1/1] START C=4.8156365982183, solver=lbfgs.............................
# [CV 4/5; 1/1] START C=4.8156365982183, solver=lbfgs.............................
# [CV 5/5; 1/1] START C=4.8156365982183, solver=lbfgs.............................
# /home/mclab/miniconda3/envs/ydl/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 1/5; 1/1] END C=4.8156365982183, solver=lbfgs;, score=0.640 total time= 1.3min
# /home/mclab/miniconda3/envs/ydl/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 4/5; 1/1] END C=4.8156365982183, solver=lbfgs;, score=0.640 total time= 1.3min
# /home/mclab/miniconda3/envs/ydl/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 3/5; 1/1] END C=4.8156365982183, solver=lbfgs;, score=0.640 total time= 1.3min
# /home/mclab/miniconda3/envs/ydl/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 5/5; 1/1] END C=4.8156365982183, solver=lbfgs;, score=0.634 total time= 1.4min
# /home/mclab/miniconda3/envs/ydl/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 2/5; 1/1] END C=4.8156365982183, solver=lbfgs;, score=0.640 total time= 1.5min
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 5/5; 1/1] START C=9.564880953047272, solver=lbfgs...........................
# [CV 2/5; 1/1] START C=9.564880953047272, solver=lbfgs...........................
# [CV 4/5; 1/1] START C=9.564880953047272, solver=lbfgs...........................
# [CV 3/5; 1/1] START C=9.564880953047272, solver=lbfgs...........................
# [CV 1/5; 1/1] START C=9.564880953047272, solver=lbfgs...........................
# /home/mclab/miniconda3/envs/ydl/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 2/5; 1/1] END C=9.564880953047272, solver=lbfgs;, score=0.639 total time= 1.4min
# /home/mclab/miniconda3/envs/ydl/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 3/5; 1/1] END C=9.564880953047272, solver=lbfgs;, score=0.641 total time= 1.4min
# /home/mclab/miniconda3/envs/ydl/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 5/5; 1/1] END C=9.564880953047272, solver=lbfgs;, score=0.633 total time= 1.5min
# /home/mclab/miniconda3/envs/ydl/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 4/5; 1/1] END C=9.564880953047272, solver=lbfgs;, score=0.639 total time= 1.5min
# /home/mclab/miniconda3/envs/ydl/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 1/5; 1/1] END C=9.564880953047272, solver=lbfgs;, score=0.640 total time= 1.5min
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 3/5; 1/1] START C=8.49838210579455, solver=lbfgs............................
# [CV 4/5; 1/1] START C=8.49838210579455, solver=lbfgs............................
# [CV 1/5; 1/1] START C=8.49838210579455, solver=lbfgs............................
# [CV 2/5; 1/1] START C=8.49838210579455, solver=lbfgs............................
# [CV 5/5; 1/1] START C=8.49838210579455, solver=lbfgs............................
# /home/mclab/miniconda3/envs/ydl/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 3/5; 1/1] END C=8.49838210579455, solver=lbfgs;, score=0.640 total time=  36.0s
# /home/mclab/miniconda3/envs/ydl/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 5/5; 1/1] END C=8.49838210579455, solver=lbfgs;, score=0.634 total time=  34.8s
# /home/mclab/miniconda3/envs/ydl/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/mclab/miniconda3/envs/ydl/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 1/5; 1/1] END C=8.49838210579455, solver=lbfgs;, score=0.641 total time=  36.8s
# [CV 4/5; 1/1] END C=8.49838210579455, solver=lbfgs;, score=0.641 total time=  37.3s
# /home/mclab/miniconda3/envs/ydl/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 2/5; 1/1] END C=8.49838210579455, solver=lbfgs;, score=0.639 total time=  38.5s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 5/5; 1/1] START C=9.729674452810828, solver=lbfgs...........................
# [CV 1/5; 1/1] START C=9.729674452810828, solver=lbfgs...........................
# [CV 2/5; 1/1] START C=9.729674452810828, solver=lbfgs...........................
# [CV 3/5; 1/1] START C=9.729674452810828, solver=lbfgs...........................
# [CV 4/5; 1/1] START C=9.729674452810828, solver=lbfgs...........................
# /home/mclab/miniconda3/envs/ydl/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 5/5; 1/1] END C=9.729674452810828, solver=lbfgs;, score=0.634 total time= 1.2min
# /home/mclab/miniconda3/envs/ydl/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 3/5; 1/1] END C=9.729674452810828, solver=lbfgs;, score=0.640 total time= 1.3min
# /home/mclab/miniconda3/envs/ydl/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 1/5; 1/1] END C=9.729674452810828, solver=lbfgs;, score=0.640 total time= 1.4min
# /home/mclab/miniconda3/envs/ydl/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 2/5; 1/1] END C=9.729674452810828, solver=lbfgs;, score=0.639 total time= 1.4min
# /home/mclab/miniconda3/envs/ydl/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 4/5; 1/1] END C=9.729674452810828, solver=lbfgs;, score=0.639 total time= 1.5min
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START C=5.487582616854288, solver=liblinear.......................
# [CV 2/5; 1/1] START C=5.487582616854288, solver=liblinear.......................
# [CV 3/5; 1/1] START C=5.487582616854288, solver=liblinear.......................
# [CV 4/5; 1/1] START C=5.487582616854288, solver=liblinear.......................
# [CV 5/5; 1/1] START C=5.487582616854288, solver=liblinear.......................
# [CV 1/5; 1/1] END C=5.487582616854288, solver=liblinear;, score=0.670 total time= 7.2min
# [CV 4/5; 1/1] END C=5.487582616854288, solver=liblinear;, score=0.667 total time= 7.4min
# [CV 5/5; 1/1] END C=5.487582616854288, solver=liblinear;, score=0.664 total time= 7.7min
# [CV 2/5; 1/1] END C=5.487582616854288, solver=liblinear;, score=0.667 total time= 7.8min
# [CV 3/5; 1/1] END C=5.487582616854288, solver=liblinear;, score=0.669 total time= 8.0min
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START C=1.2869648802400298, solver=lbfgs..........................
# [CV 2/5; 1/1] START C=1.2869648802400298, solver=lbfgs..........................
# [CV 3/5; 1/1] START C=1.2869648802400298, solver=lbfgs..........................
# [CV 5/5; 1/1] START C=1.2869648802400298, solver=lbfgs..........................
# [CV 4/5; 1/1] START C=1.2869648802400298, solver=lbfgs..........................
# /home/mclab/miniconda3/envs/ydl/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 5/5; 1/1] END C=1.2869648802400298, solver=lbfgs;, score=0.633 total time=  24.2s
# /home/mclab/miniconda3/envs/ydl/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 1/5; 1/1] END C=1.2869648802400298, solver=lbfgs;, score=0.640 total time=  28.0s
# /home/mclab/miniconda3/envs/ydl/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 3/5; 1/1] END C=1.2869648802400298, solver=lbfgs;, score=0.643 total time=  30.5s
# /home/mclab/miniconda3/envs/ydl/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 4/5; 1/1] END C=1.2869648802400298, solver=lbfgs;, score=0.639 total time=  29.2s
# /home/mclab/miniconda3/envs/ydl/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 2/5; 1/1] END C=1.2869648802400298, solver=lbfgs;, score=0.640 total time=  36.2s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START C=4.086858312895022, solver=lbfgs...........................
# [CV 5/5; 1/1] START C=4.086858312895022, solver=lbfgs...........................
# [CV 2/5; 1/1] START C=4.086858312895022, solver=lbfgs...........................
# [CV 3/5; 1/1] START C=4.086858312895022, solver=lbfgs...........................
# [CV 4/5; 1/1] START C=4.086858312895022, solver=lbfgs...........................
# /home/mclab/miniconda3/envs/ydl/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 1/5; 1/1] END C=4.086858312895022, solver=lbfgs;, score=0.641 total time= 1.1min
# /home/mclab/miniconda3/envs/ydl/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 2/5; 1/1] END C=4.086858312895022, solver=lbfgs;, score=0.640 total time=  59.0s
# /home/mclab/miniconda3/envs/ydl/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 3/5; 1/1] END C=4.086858312895022, solver=lbfgs;, score=0.641 total time=  59.9s
# /home/mclab/miniconda3/envs/ydl/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 5/5; 1/1] END C=4.086858312895022, solver=lbfgs;, score=0.633 total time= 1.0min
# /home/mclab/miniconda3/envs/ydl/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 4/5; 1/1] END C=4.086858312895022, solver=lbfgs;, score=0.639 total time= 1.0min
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 3/5; 1/1] START C=0.7178943219387851, solver=lbfgs..........................
# [CV 1/5; 1/1] START C=0.7178943219387851, solver=lbfgs..........................
# [CV 2/5; 1/1] START C=0.7178943219387851, solver=lbfgs..........................
# [CV 5/5; 1/1] START C=0.7178943219387851, solver=lbfgs..........................
# [CV 4/5; 1/1] START C=0.7178943219387851, solver=lbfgs..........................
# /home/mclab/miniconda3/envs/ydl/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 5/5; 1/1] END C=0.7178943219387851, solver=lbfgs;, score=0.634 total time=  40.3s
# /home/mclab/miniconda3/envs/ydl/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 1/5; 1/1] END C=0.7178943219387851, solver=lbfgs;, score=0.639 total time=  46.1s
# /home/mclab/miniconda3/envs/ydl/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/mclab/miniconda3/envs/ydl/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 4/5; 1/1] END C=0.7178943219387851, solver=lbfgs;, score=0.640 total time=  49.1s
# [CV 3/5; 1/1] END C=0.7178943219387851, solver=lbfgs;, score=0.641 total time=  50.3s
# /home/mclab/miniconda3/envs/ydl/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 2/5; 1/1] END C=0.7178943219387851, solver=lbfgs;, score=0.639 total time=  51.1s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START C=6.100687890800224, solver=liblinear.......................
# [CV 3/5; 1/1] START C=6.100687890800224, solver=liblinear.......................
# [CV 5/5; 1/1] START C=6.100687890800224, solver=liblinear.......................
# [CV 4/5; 1/1] START C=6.100687890800224, solver=liblinear.......................
# [CV 2/5; 1/1] START C=6.100687890800224, solver=liblinear.......................
# [CV 2/5; 1/1] END C=6.100687890800224, solver=liblinear;, score=0.667 total time= 5.1min
# [CV 4/5; 1/1] END C=6.100687890800224, solver=liblinear;, score=0.668 total time= 5.2min
# [CV 5/5; 1/1] END C=6.100687890800224, solver=liblinear;, score=0.664 total time= 5.5min
# [CV 1/5; 1/1] END C=6.100687890800224, solver=liblinear;, score=0.670 total time= 5.6min
# [CV 3/5; 1/1] END C=6.100687890800224, solver=liblinear;, score=0.669 total time= 5.6min
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START C=0.3084215815489166, solver=lbfgs..........................
# [CV 2/5; 1/1] START C=0.3084215815489166, solver=lbfgs..........................
# [CV 3/5; 1/1] START C=0.3084215815489166, solver=lbfgs..........................
# [CV 4/5; 1/1] START C=0.3084215815489166, solver=lbfgs..........................
# [CV 5/5; 1/1] START C=0.3084215815489166, solver=lbfgs..........................
# /home/mclab/miniconda3/envs/ydl/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# ...
# [CV 5/5; 1/1] START C=0.9168704234479627, solver=lbfgs..........................
# [CV 4/5; 1/1] START C=0.9168704234479627, solver=lbfgs..........................
# /home/mclab/miniconda3/envs/ydl/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 1/5; 1/1] END C=0.9168704234479627, solver=lbfgs;, score=0.640 total time=  13.4s
# /home/mclab/miniconda3/envs/ydl/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 4/5; 1/1] END C=0.9168704234479627, solver=lbfgs;, score=0.638 total time=  14.2s
# /home/mclab/miniconda3/envs/ydl/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 3/5; 1/1] END C=0.9168704234479627, solver=lbfgs;, score=0.640 total time=  17.5s
# /home/mclab/miniconda3/envs/ydl/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 2/5; 1/1] END C=0.9168704234479627, solver=lbfgs;, score=0.640 total time=  18.1s
# /home/mclab/miniconda3/envs/ydl/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 5/5; 1/1] END C=0.9168704234479627, solver=lbfgs;, score=0.634 total time=  19.1s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 5/5; 1/1] START C=1.348724427020099, solver=liblinear.......................
# [CV 1/5; 1/1] START C=1.348724427020099, solver=liblinear.......................
# [CV 3/5; 1/1] START C=1.348724427020099, solver=liblinear.......................
# [CV 2/5; 1/1] START C=1.348724427020099, solver=liblinear.......................
# [CV 4/5; 1/1] START C=1.348724427020099, solver=liblinear.......................
# [CV 1/5; 1/1] END C=1.348724427020099, solver=liblinear;, score=0.670 total time= 1.6min
# [CV 3/5; 1/1] END C=1.348724427020099, solver=liblinear;, score=0.669 total time= 1.7min
# [CV 4/5; 1/1] END C=1.348724427020099, solver=liblinear;, score=0.668 total time= 1.7min
# [CV 5/5; 1/1] END C=1.348724427020099, solver=liblinear;, score=0.664 total time= 1.7min
# [CV 2/5; 1/1] END C=1.348724427020099, solver=liblinear;, score=0.666 total time= 1.8min
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START C=8.071207657761791, solver=liblinear.......................
# [CV 2/5; 1/1] START C=8.071207657761791, solver=liblinear.......................
# [CV 3/5; 1/1] START C=8.071207657761791, solver=liblinear.......................
# [CV 4/5; 1/1] START C=8.071207657761791, solver=liblinear.......................
# [CV 5/5; 1/1] START C=8.071207657761791, solver=liblinear.......................
# [CV 5/5; 1/1] END C=8.071207657761791, solver=liblinear;, score=0.664 total time= 1.7min
# [CV 2/5; 1/1] END C=8.071207657761791, solver=liblinear;, score=0.667 total time= 1.8min
# [CV 3/5; 1/1] END C=8.071207657761791, solver=liblinear;, score=0.669 total time= 1.9min
# [CV 1/5; 1/1] END C=8.071207657761791, solver=liblinear;, score=0.670 total time= 2.0min
# [CV 4/5; 1/1] END C=8.071207657761791, solver=liblinear;, score=0.668 total time= 2.1min
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START C=0.16081323781588122, solver=liblinear.....................
# [CV 2/5; 1/1] START C=0.16081323781588122, solver=liblinear.....................
# [CV 3/5; 1/1] START C=0.16081323781588122, solver=liblinear.....................
# [CV 5/5; 1/1] START C=0.16081323781588122, solver=liblinear.....................
# [CV 4/5; 1/1] START C=0.16081323781588122, solver=liblinear.....................
# [CV 5/5; 1/1] END C=0.16081323781588122, solver=liblinear;, score=0.664 total time= 1.9min
# [CV 4/5; 1/1] END C=0.16081323781588122, solver=liblinear;, score=0.668 total time= 1.9min
# [CV 3/5; 1/1] END C=0.16081323781588122, solver=liblinear;, score=0.668 total time= 1.9min
# [CV 1/5; 1/1] END C=0.16081323781588122, solver=liblinear;, score=0.670 total time= 2.0min
# [CV 2/5; 1/1] END C=0.16081323781588122, solver=liblinear;, score=0.667 total time= 2.1min
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START C=4.607944282881714, solver=lbfgs...........................
# [CV 2/5; 1/1] START C=4.607944282881714, solver=lbfgs...........................
# [CV 3/5; 1/1] START C=4.607944282881714, solver=lbfgs...........................
# [CV 4/5; 1/1] START C=4.607944282881714, solver=lbfgs...........................
# [CV 5/5; 1/1] START C=4.607944282881714, solver=lbfgs...........................
# /home/mclab/miniconda3/envs/ydl/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 3/5; 1/1] END C=4.607944282881714, solver=lbfgs;, score=0.641 total time=  13.4s
# /home/mclab/miniconda3/envs/ydl/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/mclab/miniconda3/envs/ydl/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 2/5; 1/1] END C=4.607944282881714, solver=lbfgs;, score=0.639 total time=  15.1s
# [CV 1/5; 1/1] END C=4.607944282881714, solver=lbfgs;, score=0.641 total time=  15.2s
# /home/mclab/miniconda3/envs/ydl/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 4/5; 1/1] END C=4.607944282881714, solver=lbfgs;, score=0.637 total time=  15.6s
# /home/mclab/miniconda3/envs/ydl/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 5/5; 1/1] END C=4.607944282881714, solver=lbfgs;, score=0.633 total time=  16.0s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START C=2.426661326205444, solver=liblinear.......................
# [CV 2/5; 1/1] START C=2.426661326205444, solver=liblinear.......................
# [CV 3/5; 1/1] START C=2.426661326205444, solver=liblinear.......................
# [CV 4/5; 1/1] START C=2.426661326205444, solver=liblinear.......................
# [CV 5/5; 1/1] START C=2.426661326205444, solver=liblinear.......................
# [CV 1/5; 1/1] END C=2.426661326205444, solver=liblinear;, score=0.669 total time= 1.5min
# [CV 3/5; 1/1] END C=2.426661326205444, solver=liblinear;, score=0.667 total time= 1.5min
# [CV 4/5; 1/1] END C=2.426661326205444, solver=liblinear;, score=0.667 total time= 1.7min
# [CV 5/5; 1/1] END C=2.426661326205444, solver=liblinear;, score=0.664 total time= 1.9min
# [CV 2/5; 1/1] END C=2.426661326205444, solver=liblinear;, score=0.667 total time= 2.0min
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START C=3.2246656315796303, solver=liblinear......................
# [CV 2/5; 1/1] START C=3.2246656315796303, solver=liblinear......................
# [CV 4/5; 1/1] START C=3.2246656315796303, solver=liblinear......................
# [CV 3/5; 1/1] START C=3.2246656315796303, solver=liblinear......................
# [CV 5/5; 1/1] START C=3.2246656315796303, solver=liblinear......................
# [CV 1/5; 1/1] END C=3.2246656315796303, solver=liblinear;, score=0.670 total time= 1.6min
# [CV 5/5; 1/1] END C=3.2246656315796303, solver=liblinear;, score=0.664 total time= 1.8min
# [CV 4/5; 1/1] END C=3.2246656315796303, solver=liblinear;, score=0.668 total time= 1.9min
# [CV 2/5; 1/1] END C=3.2246656315796303, solver=liblinear;, score=0.667 total time= 2.0min
# [CV 3/5; 1/1] END C=3.2246656315796303, solver=liblinear;, score=0.669 total time= 2.0min
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 3/5; 1/1] START C=8.141774752197463, solver=lbfgs...........................
# [CV 4/5; 1/1] START C=8.141774752197463, solver=lbfgs...........................
# [CV 5/5; 1/1] START C=8.141774752197463, solver=lbfgs...........................
# [CV 2/5; 1/1] START C=8.141774752197463, solver=lbfgs...........................
# [CV 1/5; 1/1] START C=8.141774752197463, solver=lbfgs...........................
# /home/mclab/miniconda3/envs/ydl/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 5/5; 1/1] END C=8.141774752197463, solver=lbfgs;, score=0.634 total time=  13.4s
# /home/mclab/miniconda3/envs/ydl/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 2/5; 1/1] END C=8.141774752197463, solver=lbfgs;, score=0.638 total time=  15.1s
# /home/mclab/miniconda3/envs/ydl/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 4/5; 1/1] END C=8.141774752197463, solver=lbfgs;, score=0.640 total time=  18.8s
# /home/mclab/miniconda3/envs/ydl/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/mclab/miniconda3/envs/ydl/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 3/5; 1/1] END C=8.141774752197463, solver=lbfgs;, score=0.640 total time=  19.0s
# [CV 1/5; 1/1] END C=8.141774752197463, solver=lbfgs;, score=0.641 total time=  15.2s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START C=8.880959885569746, solver=liblinear.......................
# [CV 2/5; 1/1] START C=8.880959885569746, solver=liblinear.......................
# [CV 3/5; 1/1] START C=8.880959885569746, solver=liblinear.......................
# [CV 4/5; 1/1] START C=8.880959885569746, solver=liblinear.......................
# [CV 5/5; 1/1] START C=8.880959885569746, solver=liblinear.......................
# [CV 5/5; 1/1] END C=8.880959885569746, solver=liblinear;, score=0.664 total time= 1.5min
# [CV 1/5; 1/1] END C=8.880959885569746, solver=liblinear;, score=0.669 total time= 1.6min
# [CV 3/5; 1/1] END C=8.880959885569746, solver=liblinear;, score=0.669 total time= 1.8min
# [CV 4/5; 1/1] END C=8.880959885569746, solver=liblinear;, score=0.668 total time= 1.8min
# [CV 2/5; 1/1] END C=8.880959885569746, solver=liblinear;, score=0.667 total time= 2.0min
# Best parameters for Random Forest:  OrderedDict([('C', 8.071207657761791), ('solver', 'liblinear')])
# Best cross-validation score:  0.66749536141618
