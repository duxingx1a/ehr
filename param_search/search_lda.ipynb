# %%
import pandas as pd
import serach_utils
data_mean=pd.read_csv('../data_cleaned/ver-noelectrolyte-logtransform_mean.csv')
X_train,X_test,Y_train,Y_test=serach_utils.get_train_test(data_mean)

# %%
from skopt.space import Integer, Real
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from skopt.space import Real

# LDA参数空间
lda_param_space = {
    'shrinkage': Real(0, 1),  # 收缩参数
    'solver': ['lsqr', 'eigen']  # 支持shrinkage的solver
}

lda_model = LinearDiscriminantAnalysis()
serach_utils.search_params(lda_param_space, lda_model, X_train, Y_train)
